# %% [markdown]
# # Python basic stuff
#
# ## Variables and Jupyter demo

# %%
2+4+5
# Out:
# 11

# %%
a = 55

# %%
type(a)
# Out:
# int

# %%
b = 77.
b
# Out:
# 77.0

# %%
type(b)
# Out:
# float

# %%
b
# Out:
# 77.0

# %%
c
